# %%
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %%
#Download the data from the source website if necessary.

url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
#Read the data into a string.

def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
#Build the dictionary and replace rare words with UNK token.

vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5243, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %%
#Function to generate a training batch for the skip-gram model.

data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'term', 'a', 'anarchism', 'of', 'as', 'term', 'originated']

# %%
#Train a skip-gram model.

batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.978394
# Nearest to in: exaggerating, proxy, cygnus, glutamic, exclamation, obscenity, vicente, saxophonist,
# Nearest to only: alif, recitative, dem, amistad, barbosa, cosmogony, introspection, robotics,
# Nearest to s: interpret, constructors, client, piles, allegorical, gohan, listen, arginine,
# Nearest to one: finishes, bloodshed, wer, salem, contrasting, irian, sportswriter, athanasius,
# Nearest to all: energies, proof, callimico, gigue, pans, robust, unification, mond,
# Nearest to called: liberia, reorganised, phoenix, ko, slipping, geospatial, zine, df,
# Nearest to three: thorny, serene, mcintosh, jenner, pigpen, ambiguities, divides, prez,
# Nearest to on: neuroscientist, hailstones, ann, grapevine, capuchin, milt, explosive, vampire,
# Nearest to new: toonopedia, himmler, norfolk, commercialism, matchup, transitional, derivates, bread,
# Nearest to between: sabra, rescinded, songwriter, decrypted, cour, habitation, wyche, decomposing,
# Nearest to however: lancet, boyle, endow, candu, heed, tyne, cockpits, bough,
# Nearest to with: assize, guilty, caf, opinion, vendor, hattie, epa, dramatists,
# Nearest to eight: shadow, marine, theorize, resorted, hamsun, muskegon, fc, haughty,
# Nearest to when: ifor, richey, han, koizumi, gundobad, mingus, plotter, bandanese,
# Nearest to would: graphs, nutmeg, heraldry, tremolo, renounced, confederacy, hellespont, menthol,
# Nearest to after: chinon, medford, overviews, anticipating, harpers, budgeted, pairs, statement,
# Average loss at step 2000: 4.367648
# Average loss at step 4000: 3.867957
# Average loss at step 6000: 3.786879
# Average loss at step 8000: 3.691732
# Average loss at step 10000: 3.614988
# Nearest to in: of, on, from, during, at, and, by, with,
# Nearest to only: alif, amistad, robotics, expletive, sistine, dem, haste, zuid,
# Nearest to s: his, arginine, almeida, procure, and, bioethics, accepting, autistic,
# Nearest to one: two, three, eight, six, seven, four, five, mortally,
# Nearest to all: proof, lycaon, fdp, retractable, heine, flushed, other, robust,
# Nearest to called: ko, phoenix, reorganised, berklee, fez, df, legislators, used,
# Nearest to three: five, four, six, seven, eight, nine, two, zero,
# Nearest to on: in, beechcraft, from, at, drosophila, with, affair, poodle,
# Nearest to new: hovered, military, greenman, sad, beaten, hatti, bermuda, lockwood,
# Nearest to between: sabra, rescinded, with, decrypted, cour, theology, valdivia, fanning,
# Nearest to however: blue, boyle, hurrians, once, aryabhata, twelve, indonesia, dect,
# Nearest to with: by, for, into, breathtaking, on, while, abdal, between,
# Nearest to eight: nine, five, six, seven, four, three, zero, two,
# Nearest to when: pvc, concealment, ifor, dhaka, that, clc, top, terrain,
# Nearest to would: can, will, could, may, tremolo, discriminant, should, to,
# Nearest to after: for, supports, statement, medford, around, inen, evansville, old,
# Average loss at step 12000: 3.607166
# Average loss at step 14000: 3.567248
# Average loss at step 16000: 3.404954
# Average loss at step 18000: 3.461210
# Average loss at step 20000: 3.539083
# Nearest to in: at, on, cockpit, with, from, by, cybernetic, under,
# Nearest to only: schwarzenegger, not, alif, theophrastus, metrolink, haste, stocks, amistad,
# Nearest to s: almeida, medea, picasso, familiar, karlsruhe, bian, arginine, assumes,
# Nearest to one: four, two, three, six, eight, five, seven, nine,
# Nearest to all: some, those, many, fog, lycaon, these, heine, highlanders,
# Nearest to called: ko, helices, wrong, used, biot, phoenix, low, liberia,
# Nearest to three: four, five, seven, six, eight, two, nine, zero,
# Nearest to on: in, beechcraft, at, upon, milt, drosophila, through, adowa,
# Nearest to new: hovered, military, sad, my, celebration, lufthansa, risc, document,
# Nearest to between: sabra, with, against, decrypted, valdivia, by, guillaume, establishments,
# Nearest to however: but, although, if, hurrians, volunteering, dect, xiith, escalator,
# Nearest to with: between, for, in, without, by, superboy, while, at,
# Nearest to eight: nine, six, seven, four, five, three, zero, two,
# Nearest to when: after, during, kirk, but, that, pvc, dexter, was,
# Nearest to would: will, could, can, may, should, to, might, tremolo,
# Nearest to after: when, before, during, statement, for, from, supports, resizing,
# Average loss at step 22000: 3.506382
# Average loss at step 24000: 3.490597
# Average loss at step 26000: 3.481046
# Average loss at step 28000: 3.483794
# Average loss at step 30000: 3.501489
# Nearest to in: on, during, of, at, from, by, between, and,
# Nearest to only: schwarzenegger, expletive, sistine, epistolary, dionysus, alanine, binder, hessian,
# Nearest to s: his, bah, bijective, her, scream, arginine, of, wort,
# Nearest to one: two, seven, four, eight, three, five, nine, six,
# Nearest to all: some, these, many, those, fog, chronica, facie, heine,
# Nearest to called: ko, used, legislators, named, helices, erne, df, locates,
# Nearest to three: four, five, eight, seven, six, two, nine, zero,
# Nearest to on: in, upon, through, at, beechcraft, lifelong, from, danube,
# Nearest to new: military, sad, hovered, lufthansa, fjord, gaston, clement, third,
# Nearest to between: with, sabra, in, against, among, decrypted, uniting, within,
# Nearest to however: but, although, dect, if, that, since, when, assad,
# Nearest to with: between, without, for, into, among, in, while, by,
# Nearest to eight: nine, seven, six, five, four, three, zero, two,
# Nearest to when: after, during, before, if, was, where, but, while,
# Nearest to would: can, will, could, may, should, might, must, to,
# Nearest to after: before, during, when, for, in, supports, deianira, from,
# Average loss at step 32000: 3.501320
# Average loss at step 34000: 3.493467
# Average loss at step 36000: 3.450921
# Average loss at step 38000: 3.309191
# Average loss at step 40000: 3.432583
# Nearest to in: and, on, at, of, during, from, to, by,
# Nearest to only: it, no, expletive, labouring, schwarzenegger, preside, alif, epistolary,
# Nearest to s: his, her, predicates, whose, neighbour, scream, paige, did,
# Nearest to one: seven, two, four, eight, six, five, nine, three,
# Nearest to all: these, those, chronica, heine, two, fog, several, kuru,
# Nearest to called: known, ko, named, deliveries, considered, used, referred, helices,
# Nearest to three: four, five, two, seven, six, eight, nine, zero,
# Nearest to on: upon, in, at, lookup, with, beechcraft, about, between,
# Nearest to new: sad, military, hovered, modernism, manatees, lufthansa, production, kulak,
# Nearest to between: with, against, within, among, sabra, guillaume, on, in,
# Nearest to however: but, although, though, that, if, dect, overheat, which,
# Nearest to with: without, between, by, guise, in, on, against, to,
# Nearest to eight: nine, seven, six, four, five, three, zero, one,
# Nearest to when: before, while, after, if, during, where, although, as,
# Nearest to would: could, will, can, may, should, might, must, cannot,
# Nearest to after: before, during, when, while, became, edlin, deianira, for,
# Average loss at step 42000: 3.437233
# Average loss at step 44000: 3.447434
# Average loss at step 46000: 3.454926
# Average loss at step 48000: 3.357350
# Average loss at step 50000: 3.381110
# Nearest to in: on, during, within, from, of, since, between, fifo,
# Nearest to only: stocks, labouring, actually, outfield, inspires, solutes, first, epistolary,
# Nearest to s: and, whose, his, microscopes, while, heinrich, competes, evacuated,
# Nearest to one: two, eight, six, seven, four, five, three, nine,
# Nearest to all: some, chronica, these, those, highlanders, any, angell, kuru,
# Nearest to called: named, known, referred, heijenoort, pertinent, deliveries, used, ko,
# Nearest to three: four, six, seven, eight, five, nine, two, zero,
# Nearest to on: upon, in, through, at, around, against, classis, within,
# Nearest to new: hovered, sad, planckian, greenman, musical, university, manatees, modernism,
# Nearest to between: with, within, among, against, sabra, in, while, eminently,
# Nearest to however: but, although, that, though, if, while, when, since,
# Nearest to with: between, without, into, by, solanaceae, guise, while, sorting,
# Nearest to eight: six, seven, nine, four, five, three, zero, one,
# Nearest to when: after, while, before, if, although, during, where, however,
# Nearest to would: could, will, can, may, might, should, cannot, must,
# Nearest to after: before, when, during, while, helios, despite, through, for,
# Average loss at step 52000: 3.436557
# Average loss at step 54000: 3.429026
# Average loss at step 56000: 3.441505
# Average loss at step 58000: 3.402119
# Average loss at step 60000: 3.396580
# Nearest to in: within, during, on, since, of, with, from, at,
# Nearest to only: actually, canon, epistolary, still, altruists, outfield, lumped, no,
# Nearest to s: whose, evacuated, bah, paige, entrepreneurship, jsr, antithetical, overcrowded,
# Nearest to one: two, eight, four, seven, three, five, six, nine,
# Nearest to all: some, those, many, these, any, both, several, every,
# Nearest to called: used, known, named, referred, deliveries, warships, strange, considered,
# Nearest to three: five, four, six, eight, seven, two, nine, zero,
# Nearest to on: upon, in, within, through, about, classis, with, between,
# Nearest to new: particular, hovered, modernism, musical, sad, repurchase, planckian, kerenyi,
# Nearest to between: with, within, among, sabra, against, in, on, while,
# Nearest to however: but, although, though, since, when, if, that, which,
# Nearest to with: between, in, without, when, mcs, against, on, by,
# Nearest to eight: nine, six, seven, four, five, three, zero, one,
# Nearest to when: if, before, although, after, while, during, though, where,
# Nearest to would: could, will, may, can, should, might, must, cannot,
# Nearest to after: before, during, when, while, despite, for, through, helios,
# Average loss at step 62000: 3.242951
# Average loss at step 64000: 3.262718
# Average loss at step 66000: 3.405785
# Average loss at step 68000: 3.395443
# Average loss at step 70000: 3.357239
# Nearest to in: within, during, on, from, using, until, since, between,
# Nearest to only: actually, still, solutes, anything, labouring, epistolary, last, necessarily,
# Nearest to s: whose, subliminal, licks, semmelweis, evacuated, should, scream, sts,
# Nearest to one: two, seven, eight, six, four, five, nine, three,
# Nearest to all: many, some, any, both, several, every, those, these,
# Nearest to called: named, referred, used, considered, known, heijenoort, deliveries, destabilizing,
# Nearest to three: four, six, five, two, seven, eight, nine, zero,
# Nearest to on: upon, through, in, about, within, at, against, toward,
# Nearest to new: modernism, particular, kerenyi, planckian, repurchase, musical, sad, hovered,
# Nearest to between: within, with, among, in, reuss, sabra, breathtaking, from,
# Nearest to however: but, although, though, that, if, while, when, since,
# Nearest to with: between, without, emanations, follett, eviction, sorting, among, in,
# Nearest to eight: nine, six, seven, four, five, zero, three, two,
# Nearest to when: before, if, after, while, although, however, during, where,
# Nearest to would: will, could, may, can, should, might, must, cannot,
# Nearest to after: before, during, when, while, despite, for, following, through,
# Average loss at step 72000: 3.376839
# Average loss at step 74000: 3.351410
# Average loss at step 76000: 3.319717
# Average loss at step 78000: 3.353678
# Average loss at step 80000: 3.376927
# Nearest to in: during, within, on, until, at, between, since, despite,
# Nearest to only: actually, last, labouring, solutes, first, expletive, cie, necessarily,
# Nearest to s: krueger, isbn, bah, dagger, arginine, barry, sukhoi, neighbour,
# Nearest to one: seven, six, two, eight, four, five, three, nine,
# Nearest to all: both, any, many, several, some, every, various, chronica,
# Nearest to called: named, referred, known, used, considered, deliveries, evict, heijenoort,
# Nearest to three: four, six, five, seven, eight, two, nine, zero,
# Nearest to on: upon, in, through, within, against, at, during, beechcraft,
# Nearest to new: kerenyi, phases, modernism, particular, dreidel, university, importing, magical,
# Nearest to between: within, among, with, sabra, in, against, reuss, over,
# Nearest to however: although, but, though, that, while, when, where, if,
# Nearest to with: between, among, when, without, guise, against, into, eviction,
# Nearest to eight: nine, six, seven, five, four, three, zero, two,
# Nearest to when: before, after, if, during, although, while, though, where,
# Nearest to would: could, will, can, should, may, might, must, cannot,
# Nearest to after: before, during, when, despite, while, through, following, helios,
# Average loss at step 82000: 3.408659
# Average loss at step 84000: 3.413346
# Average loss at step 86000: 3.390323
# Average loss at step 88000: 3.354814
# Average loss at step 90000: 3.363452
# Nearest to in: during, within, under, between, skinned, at, from, until,
# Nearest to only: actually, labouring, either, no, epistolary, enunciated, gentiles, cie,
# Nearest to s: whose, neighbour, isbn, evacuated, agostino, monarchies, his, scream,
# Nearest to one: seven, four, two, eight, six, five, three, nine,
# Nearest to all: both, several, many, some, every, those, chronica, any,
# Nearest to called: named, referred, considered, known, used, deliveries, ballistics, clogged,
# Nearest to three: four, five, two, seven, eight, six, nine, zero,
# Nearest to on: upon, through, against, clockmaker, defeats, under, around, from,
# Nearest to new: old, particular, modernism, dreidel, weinstein, maclisp, planckian, repurchase,
# Nearest to between: within, with, among, against, sabra, uniting, in, under,
# Nearest to however: but, although, that, though, while, since, if, when,
# Nearest to with: between, in, by, including, without, among, eviction, guise,
# Nearest to eight: nine, six, seven, five, four, three, zero, two,
# Nearest to when: before, if, after, while, although, where, during, though,
# Nearest to would: could, will, may, can, might, should, must, cannot,
# Nearest to after: before, during, when, despite, while, without, following, if,
# Average loss at step 92000: 3.406542
# Average loss at step 94000: 3.253436
# Average loss at step 96000: 3.354752
# Average loss at step 98000: 3.243738
# Average loss at step 100000: 3.358439
# Nearest to in: during, within, on, from, throughout, fifo, until, at,
# Nearest to only: actually, labouring, either, still, massacred, enunciated, no, gentiles,
# Nearest to s: whose, his, isbn, andamanese, courageous, competes, housekeeping, dunsany,
# Nearest to one: two, four, seven, three, eight, five, six, nine,
# Nearest to all: every, several, those, any, both, these, many, various,
# Nearest to called: named, referred, used, known, heijenoort, and, ballistics, considered,
# Nearest to three: four, six, two, seven, five, eight, nine, zero,
# Nearest to on: upon, in, through, at, within, against, around, irda,
# Nearest to new: old, weinstein, previous, hovered, importing, breakout, particular, specific,
# Nearest to between: within, with, among, uniting, sabra, against, through, following,
# Nearest to however: but, although, though, that, while, where, realise, especially,
# Nearest to with: between, including, eviction, sorting, when, in, into, ecs,
# Nearest to eight: seven, nine, six, four, five, three, zero, two,
# Nearest to when: if, before, while, after, where, although, during, though,
# Nearest to would: could, will, should, can, may, might, must, cannot,
# Nearest to after: before, during, when, despite, without, through, while, following,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
